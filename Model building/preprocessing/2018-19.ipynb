# %%
import pandas as pd
import numpy as np
import lxml

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2018"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
# pip install lxml

# %%
dfs = [df1, df2, df3, df4]
df = pd.concat(dfs, ignore_index=True)

# %%
df
# Out:
#       Opening  Opening.1                    Title  \
# 0     JANUARY          5  Insidious: The Last Key
# 1     JANUARY          5         The Strange Ones
# 2     JANUARY         12             The Commuter
# 3     JANUARY         12               Proud Mary
# 4     JANUARY         12         Acts of Violence
# ..        ...        ...                      ...
# 237  DECEMBER         21               Second Act
# 238  DECEMBER         25          Holmes & Watson
# 239  DECEMBER         25                     Vice
# 240  DECEMBER         25      On the Basis of Sex
# 241  DECEMBER         25                Destroyer
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2        Lionsgate / StudioCanal / The Picture Company
# 3                                          Screen Gems
# 4                                   Lionsgate Premiere
# ..                                                 ...
# 237                                  STX Entertainment
# 238  Columbia Pictures / Gary Sanchez Productions /...
# 239          Annapurna Pictures / Plan B Entertainment
# 240                                     Focus Features
# 241                                 Annapurna Pictures
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Christopher Radcliff (director/screenplay); La...
# 2    Jaume Collet-Serra (director); Byron Willinger...
# 3    Babak Najafi (director); John S. Newman, Chris...
# 4    Brett Donowho (director); Nicolas Aaron Mezzan...
# ..                                                 ...
# 237  Peter Segal (director); Justin Zackham, Elaine...
# 238  Etan Cohen (director/screenplay); Will Ferrell...
# 239  Adam McKay (director/screenplay); Christian Ba...
# 240  Mimi Leder (director); Daniel Stiepleman (scre...
# 241  Karyn Kusama (director); Phil Hay, Matt Manfre...
#
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                  [2]
# 1                                                  [3]
# 2                                                  [4]
# 3                                                  [5]
# 4                                                  [6]
# ..                                                 ...
# 237                                                NaN
# 238                                                NaN
# 239                                                NaN
# 240                                                NaN
# 241                                                NaN
#
#       Ref.
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 237  [235]
# 238  [141]
# 239  [116]
# 240  [206]
# 241  [236]
#
# [242 rows x 7 columns]

# %%
# pip install tmdbv3api

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '4a1cec1f5a88caebd4b3390d00560d8e'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie()
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    movie_id = result[0].id
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
    data_json = response.json()
    if data_json['genres']:
        genre_str = " " 
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name'])
        return genre_str.join(genres)
    else:
        np.NaN

# %%
df['genres'] = df['Title'].apply(get_genre)

# %%
df
# Out:
#       Opening  Opening.1                    Title  \
# 0     JANUARY          5  Insidious: The Last Key
# 1     JANUARY          5         The Strange Ones
# 2     JANUARY         12             The Commuter
# 3     JANUARY         12               Proud Mary
# 4     JANUARY         12         Acts of Violence
# ..        ...        ...                      ...
# 237  DECEMBER         21               Second Act
# 238  DECEMBER         25          Holmes & Watson
# 239  DECEMBER         25                     Vice
# 240  DECEMBER         25      On the Basis of Sex
# 241  DECEMBER         25                Destroyer
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2        Lionsgate / StudioCanal / The Picture Company
# 3                                          Screen Gems
# 4                                   Lionsgate Premiere
# ..                                                 ...
# 237                                  STX Entertainment
# 238  Columbia Pictures / Gary Sanchez Productions /...
# 239          Annapurna Pictures / Plan B Entertainment
# 240                                     Focus Features
# 241                                 Annapurna Pictures
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Christopher Radcliff (director/screenplay); La...
# 2    Jaume Collet-Serra (director); Byron Willinger...
# 3    Babak Najafi (director); John S. Newman, Chris...
# 4    Brett Donowho (director); Nicolas Aaron Mezzan...
# ..                                                 ...
# 237  Peter Segal (director); Justin Zackham, Elaine...
# 238  Etan Cohen (director/screenplay); Will Ferrell...
# 239  Adam McKay (director/screenplay); Christian Ba...
# 240  Mimi Leder (director); Daniel Stiepleman (scre...
# 241  Karyn Kusama (director); Phil Hay, Matt Manfre...
#
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                  [2]
# 1                                                  [3]
# 2                                                  [4]
# 3                                                  [5]
# 4                                                  [6]
# ..                                                 ...
# 237                                                NaN
# 238                                                NaN
# 239                                                NaN
# 240                                                NaN
# 241                                                NaN
#
#       Ref.                                     genres
# 0      NaN                    Horror Mystery Thriller
# 1      NaN                              Drama Mystery
# 2      NaN                    Action Thriller Mystery
# 3      NaN                      Thriller Action Crime
# 4      NaN                      Action Crime Thriller
# ..     ...                                        ...
# 237  [235]                             Romance Comedy
# 238  [141]             Mystery Adventure Comedy Crime
# 239  [116]  Thriller Science Fiction Action Adventure
# 240  [206]                              Drama History
# 241  [236]                Thriller Crime Drama Action
#
# [242 rows x 8 columns]

# %%
df_2018 = df[['Title','Cast and crew','genres']]
df_2018
# Out:
#                        Title  \
# 0    Insidious: The Last Key
# 1           The Strange Ones
# 2               The Commuter
# 3                 Proud Mary
# 4           Acts of Violence
# ..                       ...
# 237               Second Act
# 238          Holmes & Watson
# 239                     Vice
# 240      On the Basis of Sex
# 241                Destroyer
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Christopher Radcliff (director/screenplay); La...
# 2    Jaume Collet-Serra (director); Byron Willinger...
# 3    Babak Najafi (director); John S. Newman, Chris...
# 4    Brett Donowho (director); Nicolas Aaron Mezzan...
# ..                                                 ...
# 237  Peter Segal (director); Justin Zackham, Elaine...
# 238  Etan Cohen (director/screenplay); Will Ferrell...
# 239  Adam McKay (director/screenplay); Christian Ba...
# 240  Mimi Leder (director); Daniel Stiepleman (scre...
# 241  Karyn Kusama (director); Phil Hay, Matt Manfre...
#
#                                         genres
# 0                      Horror Mystery Thriller
# 1                                Drama Mystery
# 2                      Action Thriller Mystery
# 3                        Thriller Action Crime
# 4                        Action Crime Thriller
# ..                                         ...
# 237                             Romance Comedy
# 238             Mystery Adventure Comedy Crime
# 239  Thriller Science Fiction Action Adventure
# 240                              Drama History
# 241                Thriller Crime Drama Action
#
# [242 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2018['director_name'] = df_2018['Cast and crew'].apply(get_director)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_9048\3992837981.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['director_name'] = df_2018['Cast and crew'].apply(get_director)

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2018['actor_1_name'] = df_2018['Cast and crew'].apply(get_actor1)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_9048\2557206127.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_1_name'] = df_2018['Cast and crew'].apply(get_actor1)

# %%
df_2018['Cast and crew'][1]
# Out:
# 'Christopher Radcliff (director/screenplay); Lauren Wolkstein (director); Alex Pettyfer, James Freedson-Jackson, Emily Althaus, Gene Jones, Owen Campbell, Tobias Campbell'

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2018['actor_2_name'] = df_2018['Cast and crew'].apply(get_actor2)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_9048\1135950138.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_2_name'] = df_2018['Cast and crew'].apply(get_actor2)

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2018['actor_3_name'] = df_2018['Cast and crew'].apply(get_actor3)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_9048\288733252.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_3_name'] = df_2018['Cast and crew'].apply(get_actor3)

# %%
df_2018
# Out:
#                        Title  \
# 0    Insidious: The Last Key
# 1           The Strange Ones
# 2               The Commuter
# 3                 Proud Mary
# 4           Acts of Violence
# ..                       ...
# 237               Second Act
# 238          Holmes & Watson
# 239                     Vice
# 240      On the Basis of Sex
# 241                Destroyer
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Christopher Radcliff (director/screenplay); La...
# 2    Jaume Collet-Serra (director); Byron Willinger...
# 3    Babak Najafi (director); John S. Newman, Chris...
# 4    Brett Donowho (director); Nicolas Aaron Mezzan...
# ..                                                 ...
# 237  Peter Segal (director); Justin Zackham, Elaine...
# 238  Etan Cohen (director/screenplay); Will Ferrell...
# 239  Adam McKay (director/screenplay); Christian Ba...
# 240  Mimi Leder (director); Daniel Stiepleman (scre...
# 241  Karyn Kusama (director); Phil Hay, Matt Manfre...
#
#                                         genres  \
# 0                      Horror Mystery Thriller
# 1                                Drama Mystery
# 2                      Action Thriller Mystery
# 3                        Thriller Action Crime
# 4                        Action Crime Thriller
# ..                                         ...
# 237                             Romance Comedy
# 238             Mystery Adventure Comedy Crime
# 239  Thriller Science Fiction Action Adventure
# 240                              Drama History
# 241                Thriller Crime Drama Action
#
#                                          director_name  \
# 0                                         Adam Robitel
# 1    Christopher Radcliff (director/screenplay); La...
# 2                                   Jaume Collet-Serra
# 3                                         Babak Najafi
# 4                                        Brett Donowho
# ..                                                 ...
# 237                                        Peter Segal
# 238                                         Etan Cohen
# 239                                         Adam McKay
# 240                                         Mimi Leder
# 241                                       Karyn Kusama
#
#                                    actor_1_name            actor_2_name  \
# 0                                     Lin Shaye           Angus Sampson
# 1    Lauren Wolkstein (director); Alex Pettyfer  James Freedson-Jackson
# 2                                   Liam Neeson            Vera Farmiga
# 3                              Taraji P. Henson    Jahi Di'Allo Winston
# 4                                  Bruce Willis             Cole Hauser
# ..                                          ...                     ...
# 237                              Jennifer Lopez             Leah Remini
# 238                                Will Ferrell          John C. Reilly
# 239                              Christian Bale               Amy Adams
# 240                              Felicity Jones            Armie Hammer
# 241                               Nicole Kidman          Sebastian Stan
#
#         actor_3_name
# 0     Leigh Whannell
# 1      Emily Althaus
# 2     Patrick Wilson
# 3        Billy Brown
# 4      Shawn Ashmore
# ..               ...
# 237  Vanessa Hudgens
# 238     Rebecca Hall
# 239     Steve Carell
# 240   Justin Theroux
# 241     Toby Kebbell
#
# [242 rows x 7 columns]

# %%
df_2018 = df_2018.rename(columns={'Title':'movie_title'})

# %%
new_df18 = df_2018.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df18
# Out:
#                                          director_name  \
# 0                                         Adam Robitel
# 1    Christopher Radcliff (director/screenplay); La...
# 2                                   Jaume Collet-Serra
# 3                                         Babak Najafi
# 4                                        Brett Donowho
# ..                                                 ...
# 237                                        Peter Segal
# 238                                         Etan Cohen
# 239                                         Adam McKay
# 240                                         Mimi Leder
# 241                                       Karyn Kusama
#
#                                    actor_1_name            actor_2_name  \
# 0                                     Lin Shaye           Angus Sampson
# 1    Lauren Wolkstein (director); Alex Pettyfer  James Freedson-Jackson
# 2                                   Liam Neeson            Vera Farmiga
# 3                              Taraji P. Henson    Jahi Di'Allo Winston
# 4                                  Bruce Willis             Cole Hauser
# ..                                          ...                     ...
# 237                              Jennifer Lopez             Leah Remini
# 238                                Will Ferrell          John C. Reilly
# 239                              Christian Bale               Amy Adams
# 240                              Felicity Jones            Armie Hammer
# 241                               Nicole Kidman          Sebastian Stan
#
#         actor_3_name                                     genres  \
# 0     Leigh Whannell                    Horror Mystery Thriller
# 1      Emily Althaus                              Drama Mystery
# 2     Patrick Wilson                    Action Thriller Mystery
# 3        Billy Brown                      Thriller Action Crime
# 4      Shawn Ashmore                      Action Crime Thriller
# ..               ...                                        ...
# 237  Vanessa Hudgens                             Romance Comedy
# 238     Rebecca Hall             Mystery Adventure Comedy Crime
# 239     Steve Carell  Thriller Science Fiction Action Adventure
# 240   Justin Theroux                              Drama History
# 241     Toby Kebbell                Thriller Crime Drama Action
#
#                  movie_title
# 0    Insidious: The Last Key
# 1           The Strange Ones
# 2               The Commuter
# 3                 Proud Mary
# 4           Acts of Violence
# ..                       ...
# 237               Second Act
# 238          Holmes & Watson
# 239                     Vice
# 240      On the Basis of Sex
# 241                Destroyer
#
# [242 rows x 6 columns]

# %%
new_df18['actor_2_name'] = new_df18['actor_2_name'].replace(np.nan, 'unknown')
new_df18['actor_3_name'] = new_df18['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df18['movie_title'] = new_df18['movie_title'].str.lower()

# %%
new_df18['comb'] = new_df18['actor_1_name'] + ' ' + new_df18['actor_2_name'] + ' '+ new_df18['actor_3_name'] + ' '+ new_df18['director_name'] + ' '+ new_df18['genres']

# %%
new_df18
# Out:
#                                          director_name  \
# 0                                         Adam Robitel
# 1    Christopher Radcliff (director/screenplay); La...
# 2                                   Jaume Collet-Serra
# 3                                         Babak Najafi
# 4                                        Brett Donowho
# ..                                                 ...
# 237                                        Peter Segal
# 238                                         Etan Cohen
# 239                                         Adam McKay
# 240                                         Mimi Leder
# 241                                       Karyn Kusama
#
#                                    actor_1_name            actor_2_name  \
# 0                                     Lin Shaye           Angus Sampson
# 1    Lauren Wolkstein (director); Alex Pettyfer  James Freedson-Jackson
# 2                                   Liam Neeson            Vera Farmiga
# 3                              Taraji P. Henson    Jahi Di'Allo Winston
# 4                                  Bruce Willis             Cole Hauser
# ..                                          ...                     ...
# 237                              Jennifer Lopez             Leah Remini
# 238                                Will Ferrell          John C. Reilly
# 239                              Christian Bale               Amy Adams
# 240                              Felicity Jones            Armie Hammer
# 241                               Nicole Kidman          Sebastian Stan
#
#         actor_3_name                                     genres  \
# 0     Leigh Whannell                    Horror Mystery Thriller
# 1      Emily Althaus                              Drama Mystery
# 2     Patrick Wilson                    Action Thriller Mystery
# 3        Billy Brown                      Thriller Action Crime
# 4      Shawn Ashmore                      Action Crime Thriller
# ..               ...                                        ...
# 237  Vanessa Hudgens                             Romance Comedy
# 238     Rebecca Hall             Mystery Adventure Comedy Crime
# 239     Steve Carell  Thriller Science Fiction Action Adventure
# 240   Justin Theroux                              Drama History
# 241     Toby Kebbell                Thriller Crime Drama Action
#
#                  movie_title  \
# 0    insidious: the last key
# 1           the strange ones
# 2               the commuter
# 3                 proud mary
# 4           acts of violence
# ..                       ...
# 237               second act
# 238          holmes & watson
# 239                     vice
# 240      on the basis of sex
# 241                destroyer
#
#                                                   comb
# 0    Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1    Lauren Wolkstein (director); Alex Pettyfer Jam...
# 2    Liam Neeson Vera Farmiga Patrick Wilson Jaume ...
# 3    Taraji P. Henson Jahi Di'Allo Winston Billy Br...
# 4    Bruce Willis Cole Hauser Shawn Ashmore Brett D...
# ..                                                 ...
# 237  Jennifer Lopez Leah Remini Vanessa Hudgens Pet...
# 238  Will Ferrell John C. Reilly Rebecca Hall Etan ...
# 239  Christian Bale Amy Adams Steve Carell Adam McK...
# 240  Felicity Jones Armie Hammer Justin Theroux Mim...
# 241  Nicole Kidman Sebastian Stan Toby Kebbell Kary...
#
# [242 rows x 7 columns]

# %%
# dataset of 2019
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2019"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
df
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_9048\3078469013.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
#       Opening  Opening.1              Title  \
# 0     JANUARY          4        Escape Room
# 1     JANUARY          4         Rust Creek
# 2     JANUARY          4   American Hangman
# 3     JANUARY         11   A Dog's Way Home
# 4     JANUARY         11         The Upside
# ..        ...        ...                ...
# 239  DECEMBER         25  Spies in Disguise
# 240  DECEMBER         25       Little Women
# 241  DECEMBER         25               1917
# 242  DECEMBER         25         Just Mercy
# 243  DECEMBER         27           Clemency
#
#                                     Production company  \
# 0                    Columbia Pictures / Original Film
# 1                       IFC Films / Lunacy Productions
# 2                          Hangman Justice Productions
# 3                                    Columbia Pictures
# 4                                    STX Entertainment
# ..                                                 ...
# 239  20th Century Fox / Blue Sky Studios / Chernin ...
# 240            Columbia Pictures / Regency Enterprises
# 241           Universal Pictures / DreamWorks Pictures
# 242          Warner Bros. Pictures / Participant Media
# 243                                               Neon
#
#                                          Cast and crew   Ref.
# 0    Adam Robitel (director); Bragi F. Schut, Maria...    [2]
# 1    Jen McGowan (director); Julie Lipson (screenpl...    [3]
# 2    Wilson Coneybeare (director/screenplay); Donal...    [4]
# 3    Charles Martin Smith (director); W. Bruce Came...    [5]
# 4    Neil Burger (director); Jon Hartmere (screenpl...    [6]
# ..                                                 ...    ...
# 239  Nick Bruno, Troy Quane (directors); Brad Copel...  [130]
# 240  Greta Gerwig (director/screenplay); Saoirse Ro...  [223]
# 241  Sam Mendes (director/screenplay); Krysty Wilso...  [224]
# 242  Destin Daniel Cretton (director/screenplay), A...  [225]
# 243  Chinonye Chukwu (director/screenplay); Alfre W...  [226]
#
# [244 rows x 6 columns]

# %%
df['genres'] = df['Title'].apply(get_genre)

# %%
df_2019 = df[['Title','Cast and crew','genres']]
df_2019
# Out:
#                  Title                                      Cast and crew  \
# 0          Escape Room  Adam Robitel (director); Bragi F. Schut, Maria...
# 1           Rust Creek  Jen McGowan (director); Julie Lipson (screenpl...
# 2     American Hangman  Wilson Coneybeare (director/screenplay); Donal...
# 3     A Dog's Way Home  Charles Martin Smith (director); W. Bruce Came...
# 4           The Upside  Neil Burger (director); Jon Hartmere (screenpl...
# ..                 ...                                                ...
# 239  Spies in Disguise  Nick Bruno, Troy Quane (directors); Brad Copel...
# 240       Little Women  Greta Gerwig (director/screenplay); Saoirse Ro...
# 241               1917  Sam Mendes (director/screenplay); Krysty Wilso...
# 242         Just Mercy  Destin Daniel Cretton (director/screenplay), A...
# 243           Clemency  Chinonye Chukwu (director/screenplay); Alfre W...
#
#                                        genres
# 0                     Horror Thriller Mystery
# 1                 Thriller Drama Action Crime
# 2                                    Thriller
# 3                      Drama Adventure Family
# 4                                Comedy Drama
# ..                                        ...
# 239  Animation Action Adventure Comedy Family
# 240                             Drama Romance
# 241                          War Action Drama
# 242                       Drama Crime History
# 243                                     Drama
#
# [244 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2019['director_name'] = df_2019['Cast and crew'].apply(get_director)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_9048\790113930.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['director_name'] = df_2019['Cast and crew'].apply(get_director)

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2019['actor_1_name'] = df_2019['Cast and crew'].apply(get_actor1)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_9048\3511002883.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_1_name'] = df_2019['Cast and crew'].apply(get_actor1)

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2019['actor_2_name'] = df_2019['Cast and crew'].apply(get_actor2)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_9048\2818543951.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_2_name'] = df_2019['Cast and crew'].apply(get_actor2)

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2019['actor_3_name'] = df_2019['Cast and crew'].apply(get_actor3)

# %%
df_2019 = df_2019.rename(columns={'Title':'movie_title'})

# %%
new_df19 = df_2019.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df19['actor_2_name'] = new_df19['actor_2_name'].replace(np.nan, 'unknown')
new_df19['actor_3_name'] = new_df19['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df19['movie_title'] = new_df19['movie_title'].str.lower()

# %%
new_df19['comb'] =  new_df19['actor_1_name'] + ' ' + new_df19['actor_2_name'] + ' '+ new_df19['actor_3_name'] + ' '+ new_df19['director_name'] +' ' + new_df19['genres']
new_df19
# Out:
#               director_name         actor_1_name          actor_2_name  \
# 0              Adam Robitel       Taylor Russell          Logan Miller
# 1               Jen McGowan    Hermione Corfield           Jay Paulson
# 2         Wilson Coneybeare    Donald Sutherland    Vincent Kartheiser
# 3      Charles Martin Smith  Bryce Dallas Howard    Edward James Olmos
# 4               Neil Burger       Bryan Cranston            Kevin Hart
# ..                      ...                  ...                   ...
# 239  Nick Bruno, Troy Quane           Will Smith           Tom Holland
# 240            Greta Gerwig        Saoirse Ronan           Emma Watson
# 241              Sam Mendes        George MacKay  Dean-Charles Chapman
# 242   Destin Daniel Cretton    Michael B. Jordan            Jamie Foxx
# 243         Chinonye Chukwu        Alfre Woodard        Wendell Pierce
#
#          actor_3_name                                    genres  \
# 0    Deborah Ann Woll                   Horror Thriller Mystery
# 1        Sean O'Bryan               Thriller Drama Action Crime
# 2       Oliver Dennis                                  Thriller
# 3     Alexandra Shipp                    Drama Adventure Family
# 4       Nicole Kidman                              Comedy Drama
# ..                ...                                       ...
# 239     Rashida Jones  Animation Action Adventure Comedy Family
# 240     Florence Pugh                             Drama Romance
# 241       Mark Strong                          War Action Drama
# 242       Brie Larson                       Drama Crime History
# 243       Aldis Hodge                                     Drama
#
#            movie_title                                               comb
# 0          escape room  Taylor Russell Logan Miller Deborah Ann Woll A...
# 1           rust creek  Hermione Corfield Jay Paulson Sean O'Bryan Jen...
# 2     american hangman  Donald Sutherland Vincent Kartheiser Oliver De...
# 3     a dog's way home  Bryce Dallas Howard Edward James Olmos Alexand...
# 4           the upside  Bryan Cranston Kevin Hart Nicole Kidman Neil B...
# ..                 ...                                                ...
# 239  spies in disguise  Will Smith Tom Holland Rashida Jones Nick Brun...
# 240       little women  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 241               1917  George MacKay Dean-Charles Chapman Mark Strong...
# 242         just mercy  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 243           clemency  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [244 rows x 7 columns]

# %%
my_df = new_df18.append(new_df19,ignore_index=True)
my_df
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_9048\3800406928.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   my_df = new_df18.append(new_df19,ignore_index=True)
#                                          director_name  \
# 0                                         Adam Robitel
# 1    Christopher Radcliff (director/screenplay); La...
# 2                                   Jaume Collet-Serra
# 3                                         Babak Najafi
# 4                                        Brett Donowho
# ..                                                 ...
# 481                             Nick Bruno, Troy Quane
# 482                                       Greta Gerwig
# 483                                         Sam Mendes
# 484                              Destin Daniel Cretton
# 485                                    Chinonye Chukwu
#
#                                    actor_1_name            actor_2_name  \
# 0                                     Lin Shaye           Angus Sampson
# 1    Lauren Wolkstein (director); Alex Pettyfer  James Freedson-Jackson
# 2                                   Liam Neeson            Vera Farmiga
# 3                              Taraji P. Henson    Jahi Di'Allo Winston
# 4                                  Bruce Willis             Cole Hauser
# ..                                          ...                     ...
# 481                                  Will Smith             Tom Holland
# 482                               Saoirse Ronan             Emma Watson
# 483                               George MacKay    Dean-Charles Chapman
# 484                           Michael B. Jordan              Jamie Foxx
# 485                               Alfre Woodard          Wendell Pierce
#
#        actor_3_name                                    genres  \
# 0    Leigh Whannell                   Horror Mystery Thriller
# 1     Emily Althaus                             Drama Mystery
# 2    Patrick Wilson                   Action Thriller Mystery
# 3       Billy Brown                     Thriller Action Crime
# 4     Shawn Ashmore                     Action Crime Thriller
# ..              ...                                       ...
# 481   Rashida Jones  Animation Action Adventure Comedy Family
# 482   Florence Pugh                             Drama Romance
# 483     Mark Strong                          War Action Drama
# 484     Brie Larson                       Drama Crime History
# 485     Aldis Hodge                                     Drama
#
#                  movie_title  \
# 0    insidious: the last key
# 1           the strange ones
# 2               the commuter
# 3                 proud mary
# 4           acts of violence
# ..                       ...
# 481        spies in disguise
# 482             little women
# 483                     1917
# 484               just mercy
# 485                 clemency
#
#                                                   comb
# 0    Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1    Lauren Wolkstein (director); Alex Pettyfer Jam...
# 2    Liam Neeson Vera Farmiga Patrick Wilson Jaume ...
# 3    Taraji P. Henson Jahi Di'Allo Winston Billy Br...
# 4    Bruce Willis Cole Hauser Shawn Ashmore Brett D...
# ..                                                 ...
# 481  Will Smith Tom Holland Rashida Jones Nick Brun...
# 482  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 483  George MacKay Dean-Charles Chapman Mark Strong...
# 484  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 485  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [486 rows x 7 columns]

# %%
old_df = pd.read_csv('../datasets/output_2017.csv')
old_df
# Out:
#               director_name          actor_1_name            actor_2_name  \
# 0             James Cameron           CCH Pounder        Joel David Moore
# 1            Gore Verbinski           Johnny Depp           Orlando Bloom
# 2                Sam Mendes       Christoph Waltz            Rory Kinnear
# 3         Christopher Nolan             Tom Hardy          Christian Bale
# 4               Doug Walker           Doug Walker              Rob Walker
# ...                     ...                   ...                     ...
# 5359            Jim Strouse      Jessica Williams            Chris O'Dowd
# 5360            Farhad Mann         Adelaide Kane  Benjamin Hollingsworth
# 5361       Hannaleena Hauru        Inka Haapamäki           Rosa Honkonen
# 5362  Jonathan A. Rosenbaum  Lou Diamond Phillips           Wallace Shawn
# 5363           Ravi Udyawar        Sridevi Kapoor               Sajal Ali
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# 3     Joseph Gordon-Levitt                  Action Thriller
# 4                  unknown                      Documentary
# ...                    ...                              ...
# 5359       Keith Stanfield                   Romance Comedy
# 5360     Jean Louisa Kelly                          Romance
# 5361        Tiitus Rantala                   Romance Comedy
# 5362           Gina Holden       Crime Comedy Action Family
# 5363        Akshaye Khanna             Crime Drama Thriller
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5359                       the incredible jessica james
# 5360                                  can't buy my love
# 5361                   thick lashes of lauri mäntyvaara
# 5362                        cop and a half: new recruit
# 5363                                                mom
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 5359  Jessica Williams Chris O'Dowd Keith Stanfield ...
# 5360  Adelaide Kane Benjamin Hollingsworth Jean Loui...
# 5361  Inka Haapamäki Rosa Honkonen Tiitus Rantala Ha...
# 5362  Lou Diamond Phillips Wallace Shawn Gina Holden...
# 5363  Sridevi Kapoor Sajal Ali Akshaye Khanna Ravi U...
#
# [5364 rows x 7 columns]

# %%
old_df.isnull().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
final_df = old_df.append(my_df,ignore_index=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_9048\2046453413.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = old_df.append(my_df,ignore_index=True)

# %%
final_df.sample(10)
# Out:
#            director_name     actor_1_name        actor_2_name  \
# 2048         Jeff Wadlow   Djimon Hounsou      Neil Brown Jr.
# 4748    Joel Paul Reisig  Joshua Ray Bell     Dana Blackstone
# 3327      Rodrigo García   Mia Wasikowska  Michael McElhatton
# 1366         Judd Apatow      Charlyne Yi        Maude Apatow
# 2640       Julien Temple  Samantha Morton     Dexter Fletcher
# 3739          Raja Menon      Nimrat Kaur     Sameer Ali Khan
# 2843            Tim Hill      Noel Fisher      Amber Valletta
# 3971         Kevin Smith      Johnny Depp   Haley Joel Osment
# 3306  David Webb Peoples     Delroy Lindo           Joan Chen
# 2713             unknown      Jacek Koman    Marian Dziedziel
#
#            actor_3_name                             genres  \
# 2048        Leslie Hope                 Action Drama Sport
# 4748     Annelyse Ahmad                             Family
# 3327      Mark Williams                              Drama
# 1366  Mackenzie Aladjem                             Comedy
# 2640       Linus Roache                    Biography Drama
# 3739        Purab Kohli  Action Drama History Thriller War
# 2843       Larry Miller                Comedy Crime Family
# 3971      Michael Parks                Comedy Drama Horror
# 3306      Anna Katarina                Action Sci-Fi Sport
# 2713   Jaroslaw Boberek        Action Crime Drama Thriller
#
#                  movie_title  \
# 2048         never back down
# 4748              horse camp
# 3327            albert nobbs
# 1366              this is 40
# 2640            pandaemonium
# 3739                 airlift
# 2843   max keeble's big move
# 3971                    tusk
# 3306     the blood of heroes
# 2713  the border
#
#                                                    comb
# 2048  Djimon Hounsou Neil Brown Jr. Leslie Hope Jeff...
# 4748  Joshua Ray Bell Dana Blackstone Annelyse Ahmad...
# 3327  Mia Wasikowska Michael McElhatton Mark William...
# 1366  Charlyne Yi Maude Apatow Mackenzie Aladjem Jud...
# 2640  Samantha Morton Dexter Fletcher Linus Roache J...
# 3739  Nimrat Kaur Sameer Ali Khan Purab Kohli Raja M...
# 2843  Noel Fisher Amber Valletta Larry Miller Tim Hi...
# 3971  Johnny Depp Haley Joel Osment Michael Parks Ke...
# 3306  Delroy Lindo Joan Chen Anna Katarina David Web...
# 2713  Jacek Koman Marian Dziedziel Jaroslaw Boberek ...

# %%
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
final_df['movie_title'] = final_df['movie_title'].str.lower()

# %%
final_df['comb'] =  final_df['movie_title'] + ' ' + final_df['comb']

# %%
final_df.to_csv('../datasets/final_data.csv',index=False)
